# %%
from datetime import datetime
name = "Oleg"
location = "Niger"

print(f"{name} start programming at {datetime.now()}. {location} is the worst city!")
# Out:
# Oleg start programming at 2026-06-01 23:20:00.544923. Niger is the worst city!

# %% [markdown]
# # My first program
